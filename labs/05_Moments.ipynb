# %% [markdown]
# # Moments: Mean, Variance, Skew, Kurtosis

# %% [markdown]
# Create a roughly normal-distributed random set of data:

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

vals = np.random.normal(0, 0.5, 10000)

plt.hist(vals, 50)
plt.show()

# %% [markdown]
# The first moment is the mean; this data should average out to about 0:

# %%
np.mean(vals)
# Out:
# -0.0023424984928069846

# %% [markdown]
# The second moment is the variance:

# %%
np.var(vals)
# Out:
# 0.2523941063032065

# %% [markdown]
# The third moment is skew - since our data is nicely centered around 0, it should be almost 0:

# %%
import scipy.stats as sp
sp.skew(vals)
# Out:
# 0.005894943420262843

# %% [markdown]
# The fourth moment is "kurtosis", which describes the shape of the tail. For a normal distribution, this is 0:

# %%
sp.kurtosis(vals)
# Out:
# 0.02561570901262611

# %% [markdown]
# ## Activity

# %% [markdown]
# Understanding skew: change the normal distribution to be centered around 10 instead of 0, and see what effect that has on the moments.
#
# The skew is still near zero; skew is associated with the shape of the distribution, not its actual offset in X.

# %%
vals = np.random.normal(0, 0.5, 100000)

plt.hist(vals, 50)
plt.show()

# %%
np.mean(vals)
# Out:
# 0.0007140432710020178

# %%
np.var(vals)
# Out:
# 0.25057016123239095

# %%
import scipy.stats as sp
sp.skew(vals)
# Out:
# -0.011666381558139554

# %%
sp.kurtosis(vals)
# Out:
# 0.037838225878715104

# %%
vals = np.random.normal(0, 1, 100000)

plt.hist(vals, 50)
plt.show()

# %%
sp.kurtosis(vals)
# Out:
# 0.0022381309360008927

# %%
vals = np.random.normal(0, 0.5, 1000000)

plt.hist(vals, 50)
plt.show()

# %%
sp.kurtosis(vals)
# Out:
# -0.0020524721398818002
